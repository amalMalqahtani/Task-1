# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
df = pd.read_csv('Task (1) Dataset.csv')

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.duplicated().empty
# Out:
# False

# %%
df.drop_duplicates("Fitness_of_casuality")
# Out:
#          Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0    17:02:00      Monday              18-30          Male
# 3     1:06:00      Sunday              18-30          Male
# 130  17:25:00    Saturday              31-50          Male
# 158  16:30:00    Saturday           Under 18          Male
# 159  16:30:00    Saturday           Under 18          Male
# 606  18:40:00      Friday              18-30          Male
#
#       Educational_level Vehicle_driver_relation Driving_experience  \
# 0     Above high school                Employee              1-2yr
# 3    Junior high school                Employee             5-10yr
# 130   Elementary school                Employee              1-2yr
# 158                 NaN                 Unknown                NaN
# 159  Junior high school                Employee         Above 10yr
# 606  Junior high school                   Owner              2-5yr
#
#          Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# ...

# %%
df.duplicated("Fitness_of_casuality")
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 12311     True
# 12312     True
# 12313     True
# 12314     True
# 12315     True
# Length: 12316, dtype: bool

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df['Time'].unique()
# Out:
# array(['17:02:00', '1:06:00', '14:15:00', ..., '7:24:00', '19:18:00',
#        '2:47:00'], dtype=object)

# %%
df['Day_of_week'].unique()
# Out:
# array(['Monday', 'Sunday', 'Friday', 'Wednesday', 'Saturday', 'Thursday',
#        'Tuesday'], dtype=object)

# %%
df['Age_band_of_driver'].unique()
# Out:
# array(['18-30', '31-50', 'Under 18', 'Over 51', 'Unknown'], dtype=object)

# %%
df['Sex_of_driver'].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %%
df['Educational_level'].unique()
# Out:
# array(['Above high school', 'Junior high school', nan,
#        'Elementary school', 'High school', 'Unknown', 'Illiterate',
#        'Writing & reading'], dtype=object)

# %%
df['Casualty_severity'].unique()
# Out:
# array(['na', '3', '2', '1'], dtype=object)

# %%
df['Age_band_of_casualty'].unique()
# Out:
# array(['na', '31-50', '18-30', 'Under 18', 'Over 51', '5'], dtype=object)

# %%
df['Work_of_casuality'].unique()
# Out:
# array([nan, 'Driver', 'Other', 'Unemployed', 'Employee', 'Self-employed',
#        'Student', 'Unknown'], dtype=object)

# %%
df['Sex_of_casualty'].unique()
# Out:
# array(['na', 'Male', 'Female'], dtype=object)

# %%
df['Casualty_class'].unique()
# Out:
# array(['na', 'Driver or rider', 'Pedestrian', 'Passenger'], dtype=object)

# %%
df['Fitness_of_casuality'].unique()
# Out:
# array([nan, 'Normal', 'Deaf', 'Other', 'Blind', 'NormalNormal'],
#       dtype=object)

# %%
df['Pedestrian_movement'].unique()
# Out:
# array(['Not a Pedestrian', "Crossing from driver's nearside",
#        'Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle',
#        'Unknown or other',
#        'Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle',
#        'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)',
#        'Walking along in carriageway, back to traffic',
#        'Walking along in carriageway, facing traffic',
#        'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing) - masked by parked or statioNot a Pedestrianry vehicle'],
#       dtype=object)

# %%
df['Cause_of_accident'].unique()
# Out:
# array(['Moving Backward', 'Overtaking', 'Changing lane to the left',
#        'Changing lane to the right', 'Overloading', 'Other',
#        'No priority to vehicle', 'No priority to pedestrian',
#        'No distancing', 'Getting off the vehicle improperly',
#        'Improper parking', 'Overspeed', 'Driving carelessly',
#        'Driving at high speed', 'Driving to the left', 'Unknown',
#        'Overturning', 'Turnover', 'Driving under the influence of drugs',
#        'Drunk driving'], dtype=object)

# %%
df['Accident_severity'].unique()
# Out:
# array(['Slight Injury', 'Serious Injury', 'Fatal injury'], dtype=object)

# %%
df['Vehicle_driver_relation'].unique()
# Out:
# array(['Employee', 'Unknown', 'Owner', nan, 'Other'], dtype=object)

# %%
df['Driving_experience'].unique()
# Out:
# array(['1-2yr', 'Above 10yr', '5-10yr', '2-5yr', nan, 'No Licence',
#        'Below 1yr', 'unknown'], dtype=object)

# %%
df['Type_of_vehicle'].unique()
# Out:
# array(['Automobile', 'Public (> 45 seats)', 'Lorry (41?100Q)', nan,
#        'Public (13?45 seats)', 'Lorry (11?40Q)', 'Long lorry',
#        'Public (12 seats)', 'Taxi', 'Pick up upto 10Q', 'Stationwagen',
#        'Ridden horse', 'Other', 'Bajaj', 'Turbo', 'Motorcycle',
#        'Special vehicle', 'Bicycle'], dtype=object)

# %%
df['Owner_of_vehicle'].unique()
# Out:
# array(['Owner', 'Governmental', nan, 'Organization', 'Other'],
#       dtype=object)

# %%
df['Driving_experience'].unique()
# Out:
# array(['1-2yr', 'Above 10yr', '5-10yr', '2-5yr', nan, 'No Licence',
#        'Below 1yr', 'unknown'], dtype=object)

# %%
df['Type_of_vehicle'].unique()
# Out:
# array(['Automobile', 'Public (> 45 seats)', 'Lorry (41?100Q)', nan,
#        'Public (13?45 seats)', 'Lorry (11?40Q)', 'Long lorry',
#        'Public (12 seats)', 'Taxi', 'Pick up upto 10Q', 'Stationwagen',
#        'Ridden horse', 'Other', 'Bajaj', 'Turbo', 'Motorcycle',
#        'Special vehicle', 'Bicycle'], dtype=object)

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df.describe().sum()
# Out:
# Number_of_vehicles_involved    12332.729468
# Number_of_casualties           12331.555328
# dtype: float64

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.groupby("Age_band_of_driver").mean(numeric_only=True)
# Out:
#                     Number_of_vehicles_involved  Number_of_casualties
# Age_band_of_driver
# 18-30                                  2.054554              1.573168
# 31-50                                  2.020798              1.565451
# Over 51                                2.031546              1.593060
# Under 18                               2.037576              1.695758
# Unknown                                2.065891              1.308786

# %%
df.groupby("Number_of_casualties").mean(numeric_only=True)
# Out:
#                       Number_of_vehicles_involved
# Number_of_casualties
# 1                                        1.948315
# 2                                        2.170306
# 3                                        2.273927
# 4                                        2.170051
# 5                                        2.734300
# 6                                        2.685393
# 7                                        2.727273
# 8                                        2.000000

# %%
df.groupby("Age_band_of_driver").mean(numeric_only=True)
# Out:
#                     Number_of_vehicles_involved  Number_of_casualties
# Age_band_of_driver
# 18-30                                  2.054554              1.573168
# 31-50                                  2.020798              1.565451
# Over 51                                2.031546              1.593060
# Under 18                               2.037576              1.695758
# Unknown                                2.065891              1.308786

# %%
df["Number_of_casualties"].count()
# Out:
# 12316

# %%
df["Day_of_week"].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0           Monday
# 1           Monday
# 2           Monday
# 3           Sunday
# 4           Sunday
#            ...
# 12311    Wednesday
# 12312       Sunday
# 12313       Sunday
# 12314       Sunday
# 12315       Sunday
# Name: Day_of_week, Length: 12316, dtype: object>

# %%
df[["Age_band_of_driver", "Accident_severity"]].mode()
# Out:
#   Age_band_of_driver Accident_severity
# 0              18-30     Slight Injury

# %%
df[["Cause_of_accident","Driving_experience","Age_band_of_driver"]]
# Out:
#                           Cause_of_accident Driving_experience  \
# 0                           Moving Backward              1-2yr
# 1                                Overtaking         Above 10yr
# 2                 Changing lane to the left              1-2yr
# 3                Changing lane to the right             5-10yr
# 4                                Overtaking              2-5yr
# ...                                     ...                ...
# 12311                         No distancing              2-5yr
# 12312                         No distancing             5-10yr
# 12313            Changing lane to the right             5-10yr
# 12314  Driving under the influence of drugs         Above 10yr
# 12315            Changing lane to the right             5-10yr
#
#       Age_band_of_driver
# 0                  18-30
# 1                  31-50
# 2                  18-30
# 3                  18-30
# 4                  18-30
# ...                  ...
# ...

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df.iloc[0:10, 2:8]
# Out:
#   Age_band_of_driver Sex_of_driver   Educational_level  \
# 0              18-30          Male   Above high school
# 1              31-50          Male  Junior high school
# 2              18-30          Male  Junior high school
# 3              18-30          Male  Junior high school
# 4              18-30          Male  Junior high school
# 5              31-50          Male                 NaN
# 6              18-30          Male  Junior high school
# 7              18-30          Male  Junior high school
# 8              18-30          Male  Junior high school
# 9              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# ...

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %%
df.plot.scatter(x="Accident_severity", y="Age_band_of_driver")
# Out:
# <Axes: xlabel='Accident_severity', ylabel='Age_band_of_driver'>

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
plt.figure()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
df.plot.scatter(x="Sex_of_casualty", y="Accident_severity", alpha=0.9)
# Out:
# <Axes: xlabel='Sex_of_casualty', ylabel='Accident_severity'>

# %%
axs = df.plot.area(figsize=(12, 4), subplots=True)

# %%
import seaborn as sns
sns.histplot("Road_surface_type")
# Out:
# <Axes: ylabel='Count'>

# %%
df.plot.scatter(x="Casualty_severity", y="Accident_severity", alpha=0.5)
# Out:
# <Axes: xlabel='Casualty_severity', ylabel='Accident_severity'>

# %%
fig, axs = plt.subplots(figsize=(6, 4))
df.plot.area(ax=axs)
axs.set_ylabel("Age_band_of_driver")
axs.set_xlabel("Accident_severity")
# Out:
# Text(0.5, 0, 'Accident_severity')

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
# no relation between 'Casualty_severity'and'Accident_severity'
# Most of employees  have a Automobile vehicle
# 18-30 the top of Age band of driver
